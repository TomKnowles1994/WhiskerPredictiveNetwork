# %%
# Seed value
seed_value = 0

# 1. Set `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.compat.v1.set_random_seed(seed_value)

# 5. Configure a new global `tensorflow` session
from tensorflow.keras import backend as K
session_conf = tf.compat.v1.ConfigProto(intra_op_parallelism_threads=1, inter_op_parallelism_threads=1)
sess = tf.compat.v1.Session(graph=tf.compat.v1.get_default_graph(), config=session_conf)
tf.compat.v1.keras.backend.set_session(sess)

# %%
import time
import numpy as np
import pandas as pd
import cv2
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.layers import Input, Layer, InputLayer, Dense, InputSpec, LSTM, Flatten, RNN, Subtract, Concatenate
from tensorflow.keras.models import Model
from tensorflow import shape, reshape
from collections import OrderedDict
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
import scipy.io as sio
from sklearn.metrics import mean_squared_error as mse

# %%
# Load Data from MATLAB file and process it into Pandas dataframe


data_matlab = sio.loadmat("C:\\Users\\Thomas\\Downloads\\200805-Whiskerdata\\2Hz_20seconds_freewhisk.mat")

mdata = data_matlab['data']

#print(mdata)

mdtype = mdata.dtype

ndata = {n: mdata[n][0, 0] for n in mdtype.names}

#print(mdtype.names)

xy_measured = ndata['xy_meas_50Hz'][0]

theta_command = ndata['theta_cmd'][0]

theta_measured = ndata['theta_meas_50Hz'][0]

## Seems to be structured Head[Row[Arc[Whisker]]]

# Row-wise extraction

#XY Whisker Data: 4 rows * 6 arcs. 24 Samples per theta measured, 240 per theta command

xy_whisker_data = pd.DataFrame()

for i in range(0,len(xy_measured)):
    for j in range(0,len(xy_measured[i])):
        column_name = 'Row {row}, Arc {arc}'.format(row = i+1, arc = j+1)
        column_data = xy_measured[i][j]
        xy_whisker_data[column_name] = column_data

print("XY: \n", xy_whisker_data)

theta_command_whisker_data = pd.DataFrame()

for i in range(0,len(theta_command)):
    column_name = 'Row {row}'.format(row = i+1)
    column_data = theta_command[i]#.repeat(10)
    theta_command_whisker_data[column_name] = column_data

print("Theta Command: \n", theta_command_whisker_data)

theta_measured_whisker_data = pd.DataFrame()

for i in range(0,len(theta_measured)):
    column_name = 'Row {row}'.format(row = i+1)
    column_data = theta_measured[i]
    theta_measured_whisker_data[column_name] = column_data

print("Theta Measured: \n", theta_measured_whisker_data)

# Theta Command repeated 10 times, to fill out rows to match XY and Theta Measured
# Theta Measured would seem to apply to only 1 whisker?
# XY is unfiltered, raw Hall Effect data
# Out:
# XY:
#        Row 1, Arc 1  Row 1, Arc 2  Row 2, Arc 1  Row 2, Arc 2  Row 3, Arc 1  \
# 0         0.003199     -0.001866      0.000224  0.000000e+00     -0.000935
# 1        -0.003999     -0.001866      0.000449 -4.488281e-04     -0.002338
# 2        -0.007465     -0.002933      0.005947  3.366211e-04     -0.004208
# 3        -0.020528     -0.002666      0.024798 -1.346484e-03     -0.005611
# 4        -0.043989      0.002399      0.030071 -7.742285e-03     -0.000935
# ...            ...           ...           ...           ...           ...
# 2195      0.015996      0.005865     -0.023339 -5.161524e-03     -0.006546
# 2196     -0.010131     -0.006665     -0.010884 -3.590625e-03      0.034601
# 2197      0.001600     -0.006665      0.005610  2.328306e-11      0.031795
# 2198      0.060519     -0.007198     -0.027491  4.263867e-03      0.031795
# 2199      0.067184     -0.005332     -0.033774  1.795313e-03      0.017300
#
#       Row 3, Arc 2  Row 4, Arc 1  Row 4, Arc 2
# 0        -0.005611     -0.000558     -0.001116
# 1        -0.005611     -0.000186     -0.000558
# 2         0.000935      0.010413     -0.001302
# 3         0.017300      0.155258     -0.056153
# 4         0.047693      0.220522     -0.102638
# ...            ...           ...           ...
# 2195     -0.014963      0.037188      0.007438
# 2196     -0.017768      0.100592     -0.002417
# 2197     -0.032730      0.148378     -0.021569
# 2198     -0.043017      0.174223     -0.021383
# 2199     -0.031328      0.165670     -0.021383
#
# [2200 rows x 8 columns]
# Theta Command:
#           Row 1     Row 2     Row 3     Row 4
# 0     0.052360  0.017453 -0.017453 -0.052360
# 1     0.130763  0.060949 -0.008864 -0.078677
# 2     0.233571  0.128852  0.024132 -0.080588
# 3     0.357617  0.217991  0.078364 -0.061262
# 4     0.498395  0.323862  0.149329 -0.025204
# ...        ...       ...       ...       ...
# 2195 -0.220614 -0.395147 -0.569680 -0.744213
# 2196 -0.228344 -0.402877 -0.577410 -0.751943
# 2197 -0.205276 -0.379809 -0.554342 -0.728875
# 2198 -0.152861 -0.327394 -0.501927 -0.676459
# 2199 -0.074390 -0.248923 -0.423456 -0.597989
#
# [2200 rows x 4 columns]
# Theta Measured:
#           Row 1     Row 2     Row 3     Row 4
# 0    -0.120187 -0.167626 -0.302961 -0.701029
# 1    -0.120379 -0.167319 -0.302923 -0.701336
# 2    -0.119459 -0.166130 -0.301044 -0.695622
# 3    -0.106458 -0.146879 -0.265609 -0.537699
# 4    -0.070410 -0.110792 -0.199954 -0.237345
# ...        ...       ...       ...       ...
# 2195 -0.013614 -0.267028 -0.476378 -0.629546
# 2196 -0.150138 -0.371147 -0.625136 -0.763040
# 2197 -0.260892 -0.425795 -0.726838 -0.845147
# 2198 -0.338626 -0.442745 -0.755025 -0.880620
# 2199 -0.366085 -0.444548 -0.716944 -0.879009
#
# [2200 rows x 4 columns]

# %%
plt.plot(xy_whisker_data['Row 1, Arc 1'][100:1000])

# %%
# Data Preprocessing - reshaping into several different varients, both overlapping and non-overlapping

data_shape = (900,1,1)
feature_range = (0,1)
data_start = 100
data_end = 1000

batch_size = 100

lag = 20

xy_3d = xy_whisker_data['Row 1, Arc 1'][data_start:data_end].to_numpy().reshape(data_shape)
xy_3d_val = xy_whisker_data['Row 1, Arc 2'][data_start:data_end].to_numpy().reshape(data_shape)
theta_command_3d = theta_command_whisker_data['Row 1'][data_start:data_end].to_numpy().reshape(data_shape)
theta_actual_3d = theta_measured_whisker_data['Row 1'][data_start:data_end].to_numpy().reshape(data_shape)

#print(xy_3d.shape, xy_3d.dtype)
#print(theta_command_3d.shape, theta_command_3d.dtype)
#print(theta_actual_3d.shape, theta_actual_3d.dtype)

# MinMaxScaling - seperate scalers used to allow descaling for predictions

xy_3d_scaler = MinMaxScaler(feature_range=feature_range)
xy_3d_scaled = xy_3d_scaler.fit_transform(xy_whisker_data['Row 1, Arc 1'][data_start:data_end].to_numpy().reshape(-1,1))

xy_3d_scaled = xy_3d_scaled.reshape(data_shape)

xy_3d_val_scaler = MinMaxScaler(feature_range=feature_range)
xy_3d_val_scaled = xy_3d_val_scaler.fit_transform(xy_whisker_data['Row 2, Arc 1'][data_start:data_end].to_numpy().reshape(-1,1))

xy_3d_val_scaled = xy_3d_val_scaled.reshape(data_shape)

theta_command_scaler = MinMaxScaler(feature_range=feature_range)
theta_command_scaled = theta_command_scaler.fit_transform(theta_command_whisker_data['Row 1'][data_start:data_end].to_numpy().reshape(-1,1))

theta_command_scaled = theta_command_scaled.reshape(data_shape)

#print(theta_command_scaled.shape)


# Without overlapping

xy_3d_no_overlap = []

for sample in range(0, xy_3d.shape[0], batch_size):
    
    xy_3d_no_overlap.append(xy_3d[sample:sample+batch_size])
    
print(len(xy_3d_no_overlap))
#print(xy_3d_no_overlap)


# With overlap

xy_3d_with_overlap = []

for sample in range(0, xy_3d.shape[0]-batch_size, 1):
    
    xy_3d_with_overlap.append(xy_3d[sample:sample+batch_size])
    
print(len(xy_3d_with_overlap))


# No overlap, for validation data (similar whisker)

xy_3d_val_no_overlap = []

for sample in range(0, xy_3d_val.shape[0], batch_size):
    
    xy_3d_val_no_overlap.append(xy_3d_val[sample:sample+batch_size])
    
print(len(xy_3d_val_no_overlap))

# No overlap, scaled

xy_3d_scaled_data = []

for sample in range(0, xy_3d_scaled.shape[0], batch_size):
    
    xy_3d_scaled_data.append(xy_3d_scaled[sample:sample+batch_size])
    
print(len(xy_3d_scaled_data))
#print(xy_3d_scaled.shape)

# No overlap, scaled, for validation data

xy_3d_val_scaled_data = []

for sample in range(0, xy_3d_val_scaled.shape[0], batch_size):
    
    xy_3d_val_scaled_data.append(xy_3d_val_scaled[sample:sample+batch_size])
    
print(len(xy_3d_val_scaled_data))

# With overlap, scaled

xy_3d_with_overlap_scaled = []

for sample in range(0, xy_3d_scaled.shape[0]-batch_size, 1):
    
    #print(sample)
    
    xy_3d_with_overlap_scaled.append(xy_3d_scaled[sample:sample+batch_size])
    
print(len(xy_3d_with_overlap_scaled))

# No overlap, for theta command data

theta_command_data = []

for sample in range(0, theta_command_3d.shape[0], batch_size):
    
    theta_command_data.append(theta_command_3d[sample:sample+batch_size])
    
print(len(theta_command_data))

# No overlap, scaled, for theta command data

theta_command_scaled_data = []

for sample in range(0, theta_command_scaled.shape[0], batch_size):
    
    theta_command_scaled_data.append(theta_command_scaled[sample:sample+batch_size])
    
print(len(theta_command_scaled_data))


# With overlap, scaled, XY data

xy_3d_with_overlap_scaled_x = []
xy_3d_with_overlap_scaled_y = []

for sample in range(lag, xy_3d_scaled.shape[0], 1):
    
    xy_3d_with_overlap_scaled_x.append(xy_3d_scaled[sample-lag:sample])
    xy_3d_with_overlap_scaled_y.append(xy_3d_scaled[sample])
    
print(len(xy_3d_with_overlap_scaled_x))
print(len(xy_3d_with_overlap_scaled_y))

X_train, y_train = np.array(xy_3d_with_overlap_scaled_x), np.array(xy_3d_with_overlap_scaled_y)

X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))


data_shape = (900,1,1)
feature_range = (0,1)
data_start = 1200
data_end = 2100

batch_size = 100

# Test data

xy_3d_with_overlap_scaled_test_x = []
test_reference = []

for sample in range(lag, xy_3d_scaled.shape[0], 1):
    
    xy_3d_with_overlap_scaled_test_x.append(xy_3d_scaled[sample-lag:sample])
    test_reference.append(xy_3d_scaled[sample])
    
print(len(xy_3d_with_overlap_scaled_test_x))

X_test = np.array(xy_3d_with_overlap_scaled_test_x)
test_reference = np.array(test_reference)

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print(len(xy_3d_with_overlap_scaled_y))

# Theta command

theta_command_scaled_x = []

for sample in range(lag, theta_command_scaled.shape[0], 1):
    
    theta_command_scaled_x.append(theta_command_scaled[sample-lag:sample])
    
print(len(theta_command_scaled_x))

X_theta = np.array(theta_command_scaled_x)
test_reference = np.array(test_reference)

X_theta = np.reshape(X_theta, (X_theta.shape[0], X_theta.shape[1], 1))

print(theta_command_scaled.shape)
print(X_train.shape)
print(X_theta.shape)
print(y_train.shape)

batch_size = 880

# Batching for new-style datasets

X_train_batched = []

for sample in range(0, X_train.shape[0], batch_size):
    
    X_train_batched.append(X_train[sample:sample+batch_size])
    
    
X_theta_batched = []

for sample in range(0, X_theta.shape[0], batch_size):
    
    X_theta_batched.append(X_theta[sample:sample+batch_size])
    
    
y_train_batched = []

for sample in range(0, y_train.shape[0], batch_size):
    
    y_train_batched.append(y_train[sample:sample+batch_size])
    
    
print(len(X_train_batched))
print(len(X_theta_batched))
print(len(y_train_batched))
# Out:
# 9
# 800
# 9
# 9
# 9
# 800
# 9
# 9
# 880
# 880
# 880
# 880
# 880
# (900, 1, 1)
# (880, 20, 1)
# (880, 20, 1)
# (880, 1, 1)
# 1
# 1
# 1

# %%
# Baseline LSTM

class WhiskerBaseline(tf.keras.Model):
    def __init__(self, output_dimensions, **kwargs):
        super().__init__(**kwargs)
        self.hidden_layer = tf.keras.layers.LSTM(12, return_sequences = True)
        self.hidden_layer2 = tf.keras.layers.LSTM(8, return_sequences = True)
        self.hidden_layer3 = tf.keras.layers.LSTM(4)
        self.output_layer = tf.keras.layers.Dense(output_dimensions)
        
    def call(self, inputs):
        Z = inputs
        Z = self.hidden_layer(Z)
        Z = self.hidden_layer2(Z)
        Z = self.hidden_layer3(Z)
        return self.output_layer(Z)
    
baseline_ar = WhiskerBaseline(output_dimensions = 1)

baseline_ar.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mae')
    
baseline_ar_train = baseline_ar.fit(X_train, y_train, epochs = 200)

plt.plot(baseline_ar_train.history['loss'])
plt.title("Baseline Mean Absolute Error per Epoch")
plt.xlabel("Epochs")
plt.ylabel("Mean Absolute Error")
# Out:
# Epoch 1/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.2176
# Epoch 2/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1855
# Epoch 3/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1830
# Epoch 4/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1824
# Epoch 5/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1818
# Epoch 6/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1824
# Epoch 7/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1813
# Epoch 8/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1804
# Epoch 9/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1800
# Epoch 10/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1801
# Epoch 11/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1798
# Epoch 12/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1794
# Epoch 13/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1786
# Epoch 14/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1789
# Epoch 15/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1784
# Epoch 16/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1787
# Epoch 17/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1784
# Epoch 18/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1775
# Epoch 19/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1783
# Epoch 20/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1782
# Epoch 21/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1746
# Epoch 22/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1731
# Epoch 23/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1720
# Epoch 24/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1738
# Epoch 25/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1690
# Epoch 26/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1696
# Epoch 27/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1724
# Epoch 28/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1688
# Epoch 29/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1681
# Epoch 30/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1677
# Epoch 31/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1683
# Epoch 32/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1718
# Epoch 33/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1687
# Epoch 34/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1676
# Epoch 35/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1678
# Epoch 36/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1685
# Epoch 37/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1672
# Epoch 38/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1665
# Epoch 39/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1665
# Epoch 40/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1666
# Epoch 41/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1660
# Epoch 42/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1686
# Epoch 43/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1660
# Epoch 44/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1664
# Epoch 45/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1661
# Epoch 46/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1662
# Epoch 47/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1649
# Epoch 48/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1624
# Epoch 49/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1722
# Epoch 50/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1652
# Epoch 51/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1644
# Epoch 52/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1648
# Epoch 53/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1649
# Epoch 54/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1617
# Epoch 55/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1607
# Epoch 56/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1624
# Epoch 57/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1590
# Epoch 58/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1621
# Epoch 59/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1620
# Epoch 60/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1590
# Epoch 61/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1574
# Epoch 62/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1573
# Epoch 63/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1589
# Epoch 64/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1571
# Epoch 65/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1544
# Epoch 66/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1556
# Epoch 67/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.1556
# Epoch 68/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1555
# Epoch 69/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1538
# Epoch 70/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1532
# Epoch 71/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1540
# Epoch 72/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1590
# Epoch 73/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1544
# Epoch 74/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1525
# Epoch 75/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1539
# Epoch 76/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1516
# Epoch 77/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1513
# Epoch 78/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1527
# Epoch 79/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1501
# Epoch 80/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1471
# Epoch 81/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1506
# Epoch 82/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1457
# Epoch 83/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1450
# Epoch 84/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1392
# Epoch 85/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1467
# Epoch 86/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1397
# Epoch 87/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1361
# Epoch 88/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1352
# Epoch 89/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1378
# Epoch 90/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1333
# Epoch 91/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1348
# Epoch 92/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1363
# Epoch 93/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1344
# Epoch 94/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1340
# Epoch 95/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1377
# Epoch 96/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1365
# Epoch 97/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1357
# Epoch 98/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1319
# Epoch 99/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1324
# Epoch 100/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1326
# Epoch 101/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1318
# Epoch 102/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1326
# Epoch 103/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1325
# Epoch 104/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1314
# Epoch 105/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1365
# Epoch 106/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1319
# Epoch 107/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1312
# Epoch 108/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1310
# Epoch 109/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1363
# Epoch 110/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1381
# Epoch 111/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1334
# Epoch 112/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1327
# Epoch 113/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1302
# Epoch 114/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1318
# Epoch 115/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1310
# Epoch 116/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1317
# Epoch 117/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1304
# Epoch 118/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1285
# Epoch 119/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1311
# Epoch 120/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1281
# Epoch 121/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1288
# Epoch 122/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1301
# Epoch 123/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1311
# Epoch 124/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1287
# Epoch 125/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1280
# Epoch 126/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1294
# Epoch 127/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1307
# Epoch 128/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1313
# Epoch 129/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1290
# Epoch 130/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1287
# Epoch 131/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1298
# Epoch 132/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1308
# Epoch 133/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1303
# Epoch 134/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1277
# Epoch 135/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1296
# Epoch 136/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1284
# Epoch 137/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1290
# Epoch 138/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1272
# Epoch 139/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1275
# Epoch 140/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1282
# Epoch 141/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1251
# Epoch 142/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1278
# Epoch 143/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1280
# Epoch 144/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1260
# Epoch 145/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1273
# Epoch 146/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1254
# Epoch 147/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1253
# Epoch 148/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1267
# Epoch 149/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1255
# Epoch 150/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1254
# Epoch 151/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1243
# Epoch 152/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1246
# Epoch 153/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1289
# Epoch 154/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1283
# Epoch 155/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1253
# Epoch 156/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1230
# Epoch 157/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1236
# Epoch 158/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1244
# Epoch 159/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1234
# Epoch 160/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1228
# Epoch 161/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1243
# Epoch 162/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1226
# Epoch 163/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1219
# Epoch 164/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1284
# Epoch 165/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1230
# Epoch 166/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1221
# Epoch 167/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1228
# Epoch 168/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1219
# Epoch 169/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1241
# Epoch 170/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1226
# Epoch 171/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1197
# Epoch 172/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1212
# Epoch 173/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1203
# Epoch 174/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1230
# Epoch 175/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1246
# Epoch 176/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1223
# Epoch 177/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1205
# Epoch 178/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1207
# Epoch 179/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1211
# Epoch 180/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1190
# Epoch 181/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1199
# Epoch 182/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1192
# Epoch 183/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1175
# Epoch 184/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1164
# Epoch 185/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1188
# Epoch 186/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1151
# Epoch 187/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1155
# Epoch 188/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1159
# Epoch 189/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1156
# Epoch 190/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1151
# Epoch 191/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1144
# Epoch 192/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1139
# Epoch 193/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1152
# Epoch 194/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1143
# Epoch 195/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1129
# Epoch 196/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1164
# Epoch 197/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1148
# Epoch 198/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1141
# Epoch 199/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1133
# Epoch 200/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1134
# Text(0, 0.5, 'Mean Absolute Error')

# %%
baseline_ar_predict = baseline_ar.predict(X_test)

plt.plot(test_reference.flatten()[:100], label = 'Ground Truth')
plt.plot(baseline_ar_predict.flatten()[:100], label = 'Predictions')

plt.title('Baseline LSTM Predictions from XY Data')

plt.legend(loc = 'lower left')

plt.xlabel('Timesteps (2Hz)')
plt.ylabel('XY Deflection')
# Out:
# Text(0, 0.5, 'XY Deflection')

# %%
baseline_theta = WhiskerBaseline(output_dimensions = 1)

baseline_theta.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), loss='mae')
    
baseline_theta_results = baseline_theta.fit(X_theta, y_train, epochs = 200)

plt.plot(baseline_theta_results.history['loss'])
plt.title("Baseline Mean Absolute Error per Epoch")
plt.xlabel("Epochs")
plt.ylabel("Mean Absolute Error")
# Out:
# Epoch 1/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.2311
# Epoch 2/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1783
# Epoch 3/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1728
# Epoch 4/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1683
# Epoch 5/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1656
# Epoch 6/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1654
# Epoch 7/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1643
# Epoch 8/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1660
# Epoch 9/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1629
# Epoch 10/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1638
# Epoch 11/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1636
# Epoch 12/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1641
# Epoch 13/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1631
# Epoch 14/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1629
# Epoch 15/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1627
# Epoch 16/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1635
# Epoch 17/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1629
# Epoch 18/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1638
# Epoch 19/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1635
# Epoch 20/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1622
# Epoch 21/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1617
# Epoch 22/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1628
# Epoch 23/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1611
# Epoch 24/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1627
# Epoch 25/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1613
# Epoch 26/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1609
# Epoch 27/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1594
# Epoch 28/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1586
# Epoch 29/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1581
# Epoch 30/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1564
# Epoch 31/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1552
# Epoch 32/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1535
# Epoch 33/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1503
# Epoch 34/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1453
# Epoch 35/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1485
# Epoch 36/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1454
# Epoch 37/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1460
# Epoch 38/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1399
# Epoch 39/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1348
# Epoch 40/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1365
# Epoch 41/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1295
# Epoch 42/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1341
# Epoch 43/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1296
# Epoch 44/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1274
# Epoch 45/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1241
# Epoch 46/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1272
# Epoch 47/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1291
# Epoch 48/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1228
# Epoch 49/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1267
# Epoch 50/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1215
# Epoch 51/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1224
# Epoch 52/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1296
# Epoch 53/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1206
# Epoch 54/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1210
# Epoch 55/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1218
# Epoch 56/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1201
# Epoch 57/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1198
# Epoch 58/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1191
# Epoch 59/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1220
# Epoch 60/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1227
# Epoch 61/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1269
# Epoch 62/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1190
# Epoch 63/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1155
# Epoch 64/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1138
# Epoch 65/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1124
# Epoch 66/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1133
# Epoch 67/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1162
# Epoch 68/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1169
# Epoch 69/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1140
# Epoch 70/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1089
# Epoch 71/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1093
# Epoch 72/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1049
# Epoch 73/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1055
# Epoch 74/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1018
# Epoch 75/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1018
# Epoch 76/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1065
# Epoch 77/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0994
# Epoch 78/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1005
# Epoch 79/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1002
# Epoch 80/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1021
# Epoch 81/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1001
# Epoch 82/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1030
# Epoch 83/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0976
# Epoch 84/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0999
# Epoch 85/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1105
# Epoch 86/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0972
# Epoch 87/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.1010
# Epoch 88/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0956
# Epoch 89/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0951
# Epoch 90/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0974
# Epoch 91/200
# 28/28 [==============================] - 0s 11ms/step - loss: 0.0930
# Epoch 92/200
# 28/28 [==============================] - 0s 7ms/step - loss: 0.0951
# Epoch 93/200
# 28/28 [==============================] - 0s 5ms/step - loss: 0.0998
# Epoch 94/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0967
# Epoch 95/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0932
# Epoch 96/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0939
# Epoch 97/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0906
# Epoch 98/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0940
# Epoch 99/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0935
# Epoch 100/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0903
# Epoch 101/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0923
# Epoch 102/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0900
# Epoch 103/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0895
# Epoch 104/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0927
# Epoch 105/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0925
# Epoch 106/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0884
# Epoch 107/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0878
# Epoch 108/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0911
# Epoch 109/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0869
# Epoch 110/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0854
# Epoch 111/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0857
# Epoch 112/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0900
# Epoch 113/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0850
# Epoch 114/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0827
# Epoch 115/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0813
# Epoch 116/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0825
# Epoch 117/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0821
# Epoch 118/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0791
# Epoch 119/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0760
# Epoch 120/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0764
# Epoch 121/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0732
# Epoch 122/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0754
# Epoch 123/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0787
# Epoch 124/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0749
# Epoch 125/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0729
# Epoch 126/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0737
# Epoch 127/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0708
# Epoch 128/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0725
# Epoch 129/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0782
# Epoch 130/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0753
# Epoch 131/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0736
# Epoch 132/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0714
# Epoch 133/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0735
# Epoch 134/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0711
# Epoch 135/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0741
# Epoch 136/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0726
# Epoch 137/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0732
# Epoch 138/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0687
# Epoch 139/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0691
# Epoch 140/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0682
# Epoch 141/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0709
# Epoch 142/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0719
# Epoch 143/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0687
# Epoch 144/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0679
# Epoch 145/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0666
# Epoch 146/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0676
# Epoch 147/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0685
# Epoch 148/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0658
# Epoch 149/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0656
# Epoch 150/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0666
# Epoch 151/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0722
# Epoch 152/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0710
# Epoch 153/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0688
# Epoch 154/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0655
# Epoch 155/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0649
# Epoch 156/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0655
# Epoch 157/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0634
# Epoch 158/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 159/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0653
# Epoch 160/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 161/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0651
# Epoch 162/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0640
# Epoch 163/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0644
# Epoch 164/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0655
# Epoch 165/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 166/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0627
# Epoch 167/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0623
# Epoch 168/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 169/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0636
# Epoch 170/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0644
# Epoch 171/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0640
# Epoch 172/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0665
# Epoch 173/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0635
# Epoch 174/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0622
# Epoch 175/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0644
# Epoch 176/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0636
# Epoch 177/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0649
# Epoch 178/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0638
# Epoch 179/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0618
# Epoch 180/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0598
# Epoch 181/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 182/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0621
# Epoch 183/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0605
# Epoch 184/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0619
# Epoch 185/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0613
# Epoch 186/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0604
# Epoch 187/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0630
# Epoch 188/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0613
# Epoch 189/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0609
# Epoch 190/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0614
# Epoch 191/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0623
# Epoch 192/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0630
# Epoch 193/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0650
# Epoch 194/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0608
# Epoch 195/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0628
# Epoch 196/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0614
# Epoch 197/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0607
# Epoch 198/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0602
# Epoch 199/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0611
# Epoch 200/200
# 28/28 [==============================] - 0s 4ms/step - loss: 0.0605
# Text(0, 0.5, 'Mean Absolute Error')

# %%
baseline_theta_predict = baseline_theta.predict(X_theta)

plt.plot(test_reference.flatten()[:100], label = 'Ground Truth')
plt.plot(baseline_theta_predict.flatten()[:100], label = 'Predictions')

plt.title("Baseline LSTM Predictions from Theta Command")

plt.legend(loc = 'lower left')

plt.ylabel('XY Deflection')
plt.xlabel('Timesteps (2Hz)')
# Out:
# Text(0.5, 0, 'Timesteps (2Hz)')

# %%
# Process contact data in the same way as the free whisking data above

data_matlab = sio.loadmat("C:\\Users\\Thomas\\Downloads\\200805-Whiskerdata\\2Hz_20seconds_contacts.mat")

mmdata = data_matlab['data']

mmdtype = mmdata.dtype

nndata = {n: mmdata[n][0, 0] for n in mmdtype.names}

xy_contacts = nndata['xy_meas_50Hz'][0]

theta_command_contacts = nndata['theta_cmd'][0]

## Seems to be structured Head[Row[Arc[Whisker]]]

# Row-wise extraction

#XY Whisker Data: 4 rows * 6 arcs. 24 Samples per theta measured, 240 per theta command

xy_contacts_data = pd.DataFrame()

for i in range(0,len(xy_contacts)):
    for j in range(0,len(xy_contacts[i])):
        column_name = 'Row {row}, Arc {arc}'.format(row = i+1, arc = j+1)
        column_data = xy_contacts[i][j]
        xy_contacts_data[column_name] = column_data

print("XY: \n", xy_whisker_data)

theta_command_contacts_data = pd.DataFrame()

for i in range(0,len(theta_command_contacts)):
    column_name = 'Row {row}'.format(row = i+1)
    column_data = theta_command_contacts[i]#.repeat(10)
    theta_command_contacts_data[column_name] = column_data

print("Theta Command: \n", theta_command_contacts_data)

xy_3d_contacts = xy_contacts_data['Row 1, Arc 1'][data_start:data_end].to_numpy().reshape(data_shape)
theta_command_3d_contacts = theta_command_contacts_data['Row 1'][data_start:data_end].to_numpy().reshape(data_shape)

# MinMaxScaling - seperate scalers used to allow descaling for predictions

xy_3d_contacts_scaler = MinMaxScaler(feature_range=feature_range)
xy_3d_contacts_scaled = xy_3d_contacts_scaler.fit_transform(xy_whisker_data['Row 1, Arc 1'][data_start:data_end].to_numpy().reshape(-1,1))

xy_3d_contacts_scaled = xy_3d_contacts_scaled.reshape(data_shape)

theta_command_contacts_scaler = MinMaxScaler(feature_range=feature_range)
theta_command_contacts_scaled = theta_command_contacts_scaler.fit_transform(theta_command_whisker_data['Row 1'][data_start:data_end].to_numpy().reshape(-1,1))

theta_command_contacts_scaled = theta_command_contacts_scaled.reshape(data_shape)

# Without overlapping, xy

xy_3d_contacts_no_overlap = []

for sample in range(0, xy_3d_contacts.shape[0], batch_size):
    
    xy_3d_contacts_no_overlap.append(xy_3d_contacts[sample:sample+batch_size])
    
# Without overlapping, with scaling, xy

xy_3d_contacts_scaled_data = []

for sample in range(0, xy_3d_contacts_scaled.shape[0], batch_size):
    
    xy_3d_contacts_scaled_data.append(xy_3d_contacts_scaled[sample:sample+batch_size])

# Without overlapping, theta command

theta_command_3d_contacts_no_overlap = []

for sample in range(0, theta_command_3d_contacts.shape[0], batch_size):
    
    theta_command_3d_contacts_no_overlap.append(theta_command_3d_contacts[sample:sample+batch_size])
    
print(len(xy_3d_contacts_no_overlap))
print(len(theta_command_3d_contacts_no_overlap))
# Out:
# XY:
#        Row 1, Arc 1  Row 1, Arc 2  Row 2, Arc 1  Row 2, Arc 2  Row 3, Arc 1  \
# 0         0.003199     -0.001866      0.000224  0.000000e+00     -0.000935
# 1        -0.003999     -0.001866      0.000449 -4.488281e-04     -0.002338
# 2        -0.007465     -0.002933      0.005947  3.366211e-04     -0.004208
# 3        -0.020528     -0.002666      0.024798 -1.346484e-03     -0.005611
# 4        -0.043989      0.002399      0.030071 -7.742285e-03     -0.000935
# ...            ...           ...           ...           ...           ...
# 2195      0.015996      0.005865     -0.023339 -5.161524e-03     -0.006546
# 2196     -0.010131     -0.006665     -0.010884 -3.590625e-03      0.034601
# 2197      0.001600     -0.006665      0.005610  2.328306e-11      0.031795
# 2198      0.060519     -0.007198     -0.027491  4.263867e-03      0.031795
# 2199      0.067184     -0.005332     -0.033774  1.795313e-03      0.017300
#
#       Row 3, Arc 2  Row 4, Arc 1  Row 4, Arc 2
# 0        -0.005611     -0.000558     -0.001116
# 1        -0.005611     -0.000186     -0.000558
# 2         0.000935      0.010413     -0.001302
# 3         0.017300      0.155258     -0.056153
# 4         0.047693      0.220522     -0.102638
# ...            ...           ...           ...
# 2195     -0.014963      0.037188      0.007438
# 2196     -0.017768      0.100592     -0.002417
# 2197     -0.032730      0.148378     -0.021569
# 2198     -0.043017      0.174223     -0.021383
# 2199     -0.031328      0.165670     -0.021383
#
# [2200 rows x 8 columns]
# Theta Command:
#           Row 1     Row 2     Row 3     Row 4
# 0     0.052360  0.017453 -0.017453 -0.052360
# 1     0.130763  0.060949 -0.008864 -0.078677
# 2     0.233571  0.128852  0.024132 -0.080588
# 3     0.357617  0.217991  0.078364 -0.061262
# 4     0.498395  0.323862  0.149329 -0.025204
# ...        ...       ...       ...       ...
# 2195 -0.220614 -0.395147 -0.569680 -0.744213
# 2196 -0.228344 -0.402877 -0.577410 -0.751943
# 2197 -0.205276 -0.379809 -0.554342 -0.728875
# 2198 -0.152861 -0.327394 -0.501927 -0.676459
# 2199 -0.074390 -0.248923 -0.423456 -0.597989
#
# [2200 rows x 4 columns]
# 2
# 2

# %%
# Test data

xy_3d_with_overlap_scaled_test_x = []
test_reference = []

for sample in range(lag, xy_3d_scaled.shape[0], 1):
    
    xy_3d_with_overlap_scaled_test_x.append(xy_3d_scaled[sample-lag:sample])
    test_reference.append(xy_3d_scaled[sample])
    
print(len(xy_3d_with_overlap_scaled_test_x))

X_test = np.array(xy_3d_with_overlap_scaled_test_x)
test_reference = np.array(test_reference)

X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

print(len(xy_3d_with_overlap_scaled_y))

# Theta command

theta_command_scaled_x = []

for sample in range(lag, theta_command_scaled.shape[0], 1):
    
    theta_command_scaled_x.append(theta_command_scaled[sample-lag:sample])
    
print(len(theta_command_scaled_x))

X_theta = np.array(theta_command_scaled_x)
test_reference = np.array(test_reference)

X_theta = np.reshape(X_theta, (X_theta.shape[0], X_theta.shape[1], 1))

print(theta_command_scaled.shape)
print(X_train.shape)
print(X_theta.shape)
print(y_train.shape)

batch_size = 880

# Batching for new-style datasets

X_train_batched = []

for sample in range(0, X_train.shape[0], batch_size):
    
    X_train_batched.append(X_train[sample:sample+batch_size])
    
    
X_theta_batched = []

for sample in range(0, X_theta.shape[0], batch_size):
    
    X_theta_batched.append(X_theta[sample:sample+batch_size])
    
    
y_train_batched = []

for sample in range(0, y_train.shape[0], batch_size):
    
    y_train_batched.append(y_train[sample:sample+batch_size])
# Out:
# 880
# 880
# 880
# (900, 1, 1)
# (880, 20, 1)
# (880, 20, 1)
# (880, 1, 1)

# %%
# Variational Autoencoder

# %%
class Representation(tf.keras.layers.Layer):
    
    def __init__(self, initialiser, **kwargs):
        super().__init__(**kwargs)
        
        self.input_layer = tf.keras.layers.LSTM(5, activation = 'tanh', recurrent_activation = 'hard_sigmoid', return_sequences = True, dynamic = True, dtype = 'float64', kernel_initializer = initialiser, recurrent_initializer = initialiser)
        #self.hidden1 = tf.keras.layers.LSTM(5, activation = 'tanh', recurrent_activation = 'hard_sigmoid', return_sequences = True, dynamic = True, dtype = 'float64', kernel_initializer = initialiser, recurrent_initializer = initialiser)
        #self.hidden2 = tf.keras.layers.LSTM(5, activation = 'tanh', recurrent_activation = 'hard_sigmoid', return_sequences = True, dynamic = True, dtype = 'float64', kernel_initializer = initialiser, recurrent_initializer = initialiser)
        self.output_layer = tf.keras.layers.LSTM(1, activation = 'tanh', recurrent_activation = 'hard_sigmoid', return_sequences = True, dynamic = True, dtype = 'float64', kernel_initializer = initialiser, recurrent_initializer = initialiser)
        
    def call(self, inputs):
    
        x = self.input_layer(inputs)
        #x = self.hidden1(x)
        #x = self.hidden2(x)
        x = self.output_layer(x)
        
        return x

# %%
# The Predictive Model - stacked LSTM and error units, similar to Cox et al. 2016

class WhiskerPredictive(tf.keras.Model):
    
    def __init__(self, stack_size, initialiser, **kwargs):
        super().__init__(**kwargs)
        
        self.first_run = True
        self.stack_size = stack_size
        
        self.ground_truth = None
        self.command = None
        
        #self.representations = [Representation(initialiser = initialiser, name = "Stack {} Representation".format(layer+1)) for layer in range(self.stack_size)]
        self.representations = [tf.keras.layers.LSTM(1, name = "Stack {} Representation".format(layer+1), activation = 'tanh', recurrent_activation = 'hard_sigmoid', return_sequences = True, dynamic = True, dtype = 'float64', kernel_initializer = initialiser, recurrent_initializer = initialiser) for layer in range(self.stack_size)]
        #self.representations = [tf.keras.layers.SimpleRNN(1, activation = 'linear', return_sequences = True, dynamic = True, dtype = 'float64', kernel_initializer = initialiser, recurrent_initializer = initialiser) for layer in range(self.stack_size)]
        self.predictions = [tf.keras.layers.Dense(1, name = "Stack {} Prediction".format(layer+1), activation = 'linear', dtype = 'float64', dynamic = True, kernel_initializer = tf.keras.initializers.Ones()) for layer in range(self.stack_size)]
        self.actual = [tf.keras.layers.Dense(1, name = "Stack {} Actual".format(layer+1), activation = 'linear', dtype = 'float64', dynamic = True, kernel_initializer = tf.keras.initializers.Ones()) for layer in range(self.stack_size+1)]
        
    def compile(self, optimiser, loss_function):
        super().compile()
        
        self.optimiser = optimiser
        self.loss_function = loss_function
        
    def call(self, ground_truth, command):
        
        if self.first_run == True:
        
            # Initialise representations and errors to zero
            
            # If it is the first run, the network will have never seen the sensory consequences before,
            # therefore no error will be present. Therefore, it will be taken to be 0. This will be
            # updated appropriately before the first model output is given.

            self.representation_cache = [tf.keras.backend.zeros_like(command) for layer in range(self.stack_size)]
            self.actual_cache = [tf.keras.backend.zeros_like(ground_truth) for layer in range(self.stack_size)]
            self.error_cache = [tf.keras.backend.zeros_like(command) for layer in range(self.stack_size)]
            self.prediction_cache = [tf.keras.backend.zeros_like(ground_truth) for layer in range(self.stack_size)]
            
        self.first_run = False
            
        self.command = command

        # Top-down pass through representations
        
        #print(self.command.shape)
        
        representation_input = tf.keras.layers.concatenate([self.command,
                                                            self.error_cache[-1]],
                                                           dtype = 'float64')
        
        #print("Representation input: ", representation_input)
        
        self.representation_cache[-1] = self.representations[-1](representation_input)
        
        if self.stack_size > 1:
        
            for layer in reversed(range(self.stack_size-1)):

                error_output = self.error_cache[layer]
                
                #prior_representation_output = self.representation_cache[layer]
                
                upper_representation_output = self.representation_cache[layer+1]

                representation_input = tf.keras.layers.concatenate([upper_representation_output, 
                                                                    error_output],
                                                                   dtype = 'float64')

                representation_output = self.representations[layer](representation_input)

                self.representation_cache[layer] = representation_output
        
        
        # Calculate error, then do a bottom-up pass to feed this back up the error stack
        
        self.prediction_cache[0] = self.predictions[0](self.representation_cache[0])
        
        self.actual_cache[0] = self.actual[0](ground_truth)
        
        self.error_cache[0] = tf.keras.layers.subtract([self.actual_cache[0], 
                                                        self.prediction_cache[0]], 
                                                       dtype = 'float64') ** 2
        
        if self.stack_size > 1:
        
            for layer in range(1,self.stack_size):

                self.prediction_cache[layer] = self.predictions[layer](self.representation_cache[layer])

                self.actual_cache[layer] = self.actual[layer](self.error_cache[layer-1])

                self.error_cache[layer] = tf.keras.layers.subtract([self.actual_cache[layer], 
                                                                    self.prediction_cache[layer]], 
                                                                   dtype = 'float64') ** 2
        
            
        return self.actual_cache, self.prediction_cache
    
    
    def train(self, train_sensory, train_command, val_sensory, val_command, epochs = 10):
        
        training_loss = OrderedDict()
        
        validation_loss = OrderedDict()
        
        for epoch in range(epochs):
            
            batch_train_losses = []
            
            batch_val_losses = []
            
            print("Epoch ", epoch+1)
            
            for n_batch in range(len(train_sensory)):
                
                # Train
                
                with tf.GradientTape() as tape:
                    
                    # Gradients calculated comparing output predictions to target values.
                    # The error units thus provide an implicit measurement of performance for 
                    # weight updates
                    
                    train_actuals_out, train_predictions_out = self.call(train_sensory[n_batch], train_command[n_batch])
                    
                    #print(np.array(self.error_cache).shape)
                    #print(np.array(train_actuals_out).shape)
                    #print(np.array(train_predictions_out).shape)
                    
                    train_loss = self.error_cache
                
                gradients = tape.gradient(train_loss, self.trainable_weights)
                
                batch_train_losses.append(np.mean(train_loss))

                self.optimiser.apply_gradients(zip(gradients, self.trainable_weights))
                
            epoch_train_loss = np.mean(batch_train_losses)

            training_loss[epoch+1] = epoch_train_loss
                
            print("Mean Training Error: {}".format(epoch_train_loss))
            
            # Validation currently not used until the algorithm is functioning properly
                
            if val_sensory is not None:
        
                for n_batch in range(len(val_sensory)):
                
                    # Validate

                    val_error_out, val_rep_out = self.call(val_sensory[n_batch], val_command[n_batch])

                    val_loss = self.loss_function(val_error_out, val_rep_out)

                    batch_val_losses.append(np.mean(val_loss.numpy().flatten()))

                epoch_val_loss = np.mean(batch_val_losses)

                validation_loss[epoch+1] = epoch_val_loss            
            
                print("Mean Validation Error: {}".format(epoch_val_loss))

        return training_loss, validation_loss
    
    def predict(self, input_sensory, theta_command):
        
        # Call the trained network repeatedly and return the output values
        
        prediction_losses = []
        
        predicted_values = []
        
        for n_batch in range(len(input_sensory)):

            _, pred_rep_out = self.call(input_sensory[n_batch], theta_command[n_batch])
            
            predicted_values.append(pred_rep_out[0])

            prediction_loss = self.loss_function(input_sensory[n_batch], pred_rep_out[0])

            prediction_losses.append(prediction_loss)
            
            #print("Input: ", input_sensory[n_batch], "Prediction: ", pred_rep_out[0])
            
        return predicted_values, prediction_losses
    
    def simple_test(self, input_sensory, theta_command, runs):
        
        # A small test routine to ensure the information is passed through the network correctly
        # (requires making activations linear first)
        
        for run in range(0, runs):
        
            test_actual_out, test_pred_out = self.call(input_sensory[run], theta_command)
            
            test_error_out = np.subtract(test_actual_out, test_pred_out) ** 2
            
            print("Output Prediction: ", test_pred_out)
            
            print("Output Actual: ", test_actual_out)
            
            print("Output Error: ", test_error_out, "\n")

# Next: 1 more core capability to add: Feed in contact data, report errors, map to known contacts
# i.e. predict contacts from where high prediction error is encountered

# Requires:

# A robust model that can distinguish contacts from non-contacts
# A 'contacts' method, for showing only when error is above a threshold

# %% [raw]
# # Running the test routine
#
# predictive_test = WhiskerPredictive(stack_size = 2, initialiser = tf.keras.initializers.Ones())
#
# predictive_test.compile(optimiser=tf.keras.optimizers.Adam(learning_rate=0.0001),
#                         loss_function=tf.keras.losses.MeanAbsoluteError())
#
#
# test_input = [tf.keras.backend.ones((1,1,1), dtype = 'float64')] * 5
#
# #test_input = [tf.keras.backend.ones((1,1,1), dtype = 'float64') * 0.1,
# #              tf.keras.backend.ones((1,1,1), dtype = 'float64') * 0.2,
# #              tf.keras.backend.ones((1,1,1), dtype = 'float64') * 0.3,
# #              tf.keras.backend.ones((1,1,1), dtype = 'float64') * 0.4,
# #              tf.keras.backend.ones((1,1,1), dtype = 'float64') * 0.5]
#
# #print("Input = ", test_input)
#
# test_command = [tf.keras.backend.ones((1,1,1), dtype = 'float64')] * 5
#
# test_out = predictive_test.simple_test(input_sensory = test_input,
#                                        theta_command = test_command,
#                                        runs = len(test_input))

# %%
# Running the actual training

predictive_test = WhiskerPredictive(stack_size = 3, initialiser = tf.keras.initializers.RandomNormal(mean=0.5, stddev=1.))

predictive_test.compile(optimiser=tf.keras.optimizers.Adam(learning_rate=0.0001),
                        loss_function=tf.keras.losses.MeanAbsoluteError())

history = predictive_test.train(train_sensory = X_train_batched,
                                train_command = X_theta_batched,
                                val_sensory = None,
                                val_command = None)
# Out:
# WARNING:tensorflow:Layer Stack 1 Representation will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer Stack 2 Representation will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# WARNING:tensorflow:Layer Stack 3 Representation will not use cuDNN kernel since it doesn't meet the cuDNN kernel criteria. It will use generic GPU kernel as fallback when running on GPU
# Epoch  1
# Mean Training Error: 0.42673563181080976
# Epoch  2
# Mean Training Error: 0.11114265444897077
# Epoch  3
# Mean Training Error: 0.228824341470722
# Epoch  4
# Mean Training Error: 0.08566081341425556
# Epoch  5
# Mean Training Error: 0.2695850899981991
# Epoch  6
# Mean Training Error: 0.09538955059220558
# Epoch  7
# Mean Training Error: 0.2395566990544569
# Epoch  8
# Mean Training Error: 0.09599996949111536
# Epoch  9
# Mean Training Error: 0.2315874260181043
# Epoch  10
# Mean Training Error: 0.09955045650710989

# %%
history[0].values()

def unpack_values(dictionary):
    
    list_out = []
    
    for value in dictionary.values():
        
        list_out.append(value)
        
    return list_out

history_train = unpack_values(history[0])
history_val = unpack_values(history[1])

# %%
plt.plot(history_train)
plt.plot(history_val)

plt.ylabel('Mean Absolute Error')
plt.xlabel('Epoch')

plt.title("Mean Training Error per Epoch")
# Out:
# Text(0.5, 1.0, 'Mean Training Error per Epoch')

# %%
# Predict

predictions = predictive_test.predict(input_sensory = y_train_batched, 
                                      theta_command = X_theta_batched)

# %%
flat_predictions = predictions[0][0].numpy().flatten()
flat_scaled_data = np.array(xy_3d_scaled_data[0]).flatten()
flat_theta_command_scaled = np.array(theta_command_scaled_data[0]).flatten()
flat_data_no_scale = np.array(xy_3d[0]).flatten()
flat_theta_command_no_scale = np.array(theta_command_3d[0]).flatten()

plt.plot(flat_scaled_data[:100])

prediction_scaler = MinMaxScaler(feature_range=feature_range)
scaled_predictions = prediction_scaler.fit_transform(flat_predictions.reshape(-1,1))

plt.plot(scaled_predictions[:100])

plt.title("Ground Truth (blue) vs Predictions (orange), scaled (-1, 1)")
# Out:
# Text(0.5, 1.0, 'Ground Truth (blue) vs Predictions (orange), scaled (-1, 1)')

# %%
sorted_predictions = []

for prediction in range(0, len(scaled_predictions)):
    
    if prediction > 18 and prediction % 20 == 0:
        
        sorted_predictions.append(scaled_predictions.flatten()[prediction])
        
print(sorted_predictions)
# Out:
# [0.34185834583418423, 0.39778254858663836, 0.3556326325268338, 0.4073379573063435, 0.3272184775850434, 0.3671735653506277, 0.3742508294611069, 0.3190220319863266, 0.44515081416619146, 0.38012352805001337, 0.30974775116451697, 0.31636919819662923, 0.3231974925947586, 0.4096587208118419, 0.5495931776709264, 0.32605733668989584, 0.3796465730795515, 0.34503383768401846, 0.3465961434984951, 0.40688341504875764, 0.37514830721064624, 0.4169561587376314, 0.6315004088969013, 0.6340499526378378, 0.43185162132081095, 0.3558406371051867, 0.417016925858615, 0.3513907614327979, 0.42577311284666575, 0.3276199045321207, 0.37972759535121126, 0.38527950025713886, 0.3190220325873799, 0.43567226278238375, 0.41105487139665015, 0.31897520858690254, 0.3217164251583627, 0.36042113631021416, 0.42854719355663895, 0.5204659653109807, 0.32527348751204543, 0.3772487619201239, 0.33453078556368343, 0.35068086124916775, 0.4075993693630157, 0.3939709389234427, 0.41173466329899416, 0.6070016868545376, 0.6050247363366102, 0.4662361485605895, 0.3558406369336106, 0.42943186209489514, 0.3361708797854939, 0.41305168357688793, 0.350890906789274, 0.39566024668493405, 0.4043726446619282, 0.3230180817094683, 0.4131702378254277, 0.39700395845623015, 0.31546875697010707, 0.3278135582179065, 0.35925850444219926, 0.4104480856670094, 0.5365219944683547, 0.3241244547957368, 0.3897475940084633, 0.34140043986361795, 0.34025718197634813, 0.4134345192067327, 0.3814761129711709, 0.4254494548221889, 0.6270479397038303, 0.632935120036094, 0.45344084037300114, 0.359876812180101, 0.43284929268677574, 0.3369876571348917, 0.4310397359038204, 0.32126688376585966, 0.34972574500778597, 0.4251764920711957, 0.3022614021576536, 0.49288445907331724, 0.3715538065473935, 0.3095291933645644, 0.31436450770250207, 0.3244176623754022, 0.413634934216552, 0.5078858900586705, 0.32376305695841306, 0.3871464534636454, 0.3390272531430666, 0.35433367522767767, 0.43532171248687557, 0.39331630928090605, 0.41620141969344077, 0.5672474200173004, 0.6307046219426526, 0.45254569732080296, 0.3539028576398582, 0.4098788701087161, 0.38617671022039146, 0.42231798805332055, 0.3492095699676924, 0.37332157527841925, 0.39381264711001873, 0.31643049314413646, 0.4237526872726562, 0.39382400688530755, 0.31291854881004266, 0.3266644752019492, 0.33535750275467063, 0.4461725438228019, 0.5006686709265535, 0.3234783547654901, 0.39106696493489446, 0.3440006812457356, 0.3448789390963107, 0.41269473082949615, 0.3802965737727021, 0.44515964374130773, 0.6415029021053322, 0.659565328185624, 0.4843497915748691, 0.3342966374327049, 0.42190614046537106, 0.33617087801723716, 0.43640549493737313, 0.3382817775029905, 0.3705570987212798, 0.41543500338310424, 0.3075229820555637, 0.496079382192393, 0.3492080564954066, 0.3095291933645644, 0.3237531646907311, 0.35753921710908604, 0.3989204078644345, 0.5016939553998281, 0.3241986198652477, 0.368175522524673, 0.3453852263998964, 0.3432496658792444, 0.4336849022571671, 0.3946286792102696, 0.4538289413761457, 0.6303875872405292, 0.5949957195793267, 0.47950311874426504, 0.3396280299622388, 0.4122318748575578, 0.34542938539701834, 0.42060740161793597, 0.33925868101692463, 0.39884860062855865, 0.40271497661363126, 0.3194061138237889, 0.4451508129913238, 0.3634439264606184, 0.30829460742276643, 0.312591976308522, 0.32013616599766753, 0.3959609289706941, 0.4845394578718332, 0.32504299448878493, 0.383965927680244, 0.34948025151790885, 0.3423145416176281, 0.45935991810235854, 0.3869422570551427, 0.4095412253550239, 0.5381831826369394, 0.5805738109157341, 0.48240447359714744, 0.34072754746579237, 0.4022284628127343, 0.3690039640019183, 0.42060740251129614, 0.3417599640079259, 0.3797275954780188, 0.37496399372468825, 0.3190220324538125, 0.42555609595180194, 0.37793837181962187, 0.3077269070640456, 0.3116032225095684, 0.3198793967718979, 0.4080888536919259, 0.4805919641460441, 0.32650083520246287, 0.39374311140407847, 0.34794257028442477, 0.3518675571821978, 0.4134345194656798, 0.36664848232433545, 0.4038237 ...

# %%
plt.plot(flat_scaled_data[:100], label = 'Ground Truth')
plt.plot(sorted_predictions[:100], label = 'Predictions')

plt.title("Multi-timestep Network Predictions")

plt.legend(loc = 'lower left')

plt.ylabel('XY Deflection')
plt.xlabel('Timesteps (2Hz)')
# Out:
# Text(0.5, 0, 'Timesteps (2Hz)')

# %%
plt.plot(xy_whisker_data['Row 1, Arc 1'][:100])
plt.plot(flat_predictions[:100])

plt.title("Original Whisker Data (blue) vs Predictions (orange), raw")
# Out:
# Text(0.5, 1.0, 'Original Whisker Data (blue) vs Predictions (orange), raw')

# %%
plt.plot(theta_command_whisker_data['Row 1'][:100])
plt.plot(flat_predictions[:100])
plt.title("Raw Predictions overlaid on Theta Command Signal (not currently used)")
# Out:
# Text(0.5, 1.0, 'Raw Predictions overlaid on Theta Command Signal (not currently used)')

# %%
prediction_training_data = predictive_test.predict(input_sensory = X_train_batched, 
                                                   theta_command = X_theta_batched)

flat_prediction_training_data = []

for batch in range(len(prediction_training_data[0])):
    
    flat_prediction_training_data.extend(prediction_training_data[0][batch].numpy().flatten())

#flat_prediction_training_data = prediction_training_data[0][0].numpy().flatten()

prediction_contacts = predictive_test.predict(input_sensory = xy_3d_contacts_scaled_data, 
                                              theta_command = None)

flat_prediction_contacts = []

for batch in range(len(prediction_contacts[0])):
    
    flat_prediction_contacts.extend(prediction_contacts[0][batch].numpy().flatten())

#flat_prediction_contacts = prediction_contacts[0][0].numpy().flatten()


error_no_contacts = np.subtract(xy_whisker_data['Row 1, Arc 1'][data_start:data_end].to_list(), 
                        flat_prediction_training_data)

error_contacts = np.subtract(xy_contacts_data['Row 1, Arc 1'][data_start:data_end].to_list(), 
                     flat_prediction_contacts)

plt.plot(flat_prediction_training_data)
plt.plot(error_no_contacts)

plt.title("Predictions (blue) and Errors (orange), No Contact (Free Whisking) Data")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-bf137a252e2f> in <module>
#      11
#      12 prediction_contacts = predictive_test.predict(input_sensory = xy_3d_contacts_scaled_data,
# ---> 13                                               theta_command = None)
#      14
#      15 flat_prediction_contacts = []
#
# <ipython-input-14-3b0d42fe41e8> in predict(self, input_sensory, theta_command)
#     176         for n_batch in range(len(input_sensory)):
#     177
# --> 178             _, pred_rep_out = self.call(input_sensory[n_batch], theta_command[n_batch])
#     179
#     180             predicted_values.append(pred_rep_out[0])
#
# TypeError: 'NoneType' object is not subscriptable

# %%
plt.plot(flat_prediction_contacts)
plt.plot(error_contacts)

plt.title("Predictions (blue) and Errors (orange), Contact (Non-Free Whisking) Data")

# %%
contact_none_difference = np.subtract(xy_contacts_data['Row 1, Arc 1'][data_start:data_end].to_list(), 
                                      xy_whisker_data['Row 1, Arc 1'][data_start:data_end].to_list())

# %%
plt.plot(contact_none_difference)
plt.title("Difference between no-contact and contact whisking")

# %%
detected_error_training = np.subtract(error_no_contacts, 
                                      flat_prediction_training_data) ** 2

# %%
detected_error_contacts = np.subtract(error_contacts, 
                                      flat_prediction_contacts) ** 2

# %%
plt.plot(detected_error_training)
plt.plot(detected_error_contacts)

plt.title("Error Detected for No-contact Whisking (blue) and Contact Whisking (orange)")
